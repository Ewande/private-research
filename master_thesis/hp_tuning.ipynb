# %% [markdown]
# GA
# ---
#
# epochs $= 20$
# num_positions $= 3$
# seeds $\in \{1, 2, 3, 4, 5\} $
#
# **STATIC**
#
# initial config:
# - p_mut $= 0.03$
# - p_cross $= 0.75$
# - selection $=$ tournament, size $3$
# - param init $= (-1, 1)$
# - population size $= 100$
#
#
# -- population size $\in \{50, 75, 100, 125, 150, 175, 200\}$
#
# | param value | average fitness |
# |------------:|----------------:|
# |          50 |          0.1015 |
# |          75 |          0.1043 |
# |         100 |          0.1059 |
# |         125 |          0.1151 |
# |       **150** |      **0.1177** |
# |         175 |          0.1102 |
# |         200 |          0.1177 |
#
# -- p_cross $\in \{0.70, 0.75, 0.80, 0.85, 0.90, 0.95\}$
#
# | param value | average fitness |
# |------------:|----------------:|
# |        0.70 |          0.1124 |
# |      **0.75** |      **0.1177** |
# |        0.80 |          0.1111 |
# |        0.85 |          0.1177 |
# |        0.90 |          0.1170 |
# |        0.95 |          0.1151 |
# |        0.99 |          0.1160 |
#
# -- p_mut $\in \{0.01, 0.02, 0.03, 0.05\}$
#
# | param value | average fitness |
# |------------:|----------------:|
# |        0.01 |          0.1177 |
# |      **0.02** |      **0.1195** |
# |        0.03 |          0.1177 |
# |        0.05 |          0.1182 |
#
# -- selection $\in \{ t1, t2, t3, t4, t5, t6, wheel \}$
#
# | param value | average fitness |
# |------------:|----------------:|
# |          t1 |          0.0753 |
# |          t2 |          0.1051 |
# |          t3 |          0.1195 |
# |          t4 |          0.1146 |
# |          t5 |          0.1198 |
# |       ** t6 ** |     **0.1223** |
# |          t7 |          0.1132 |
# |       wheel |          0.1056 |
#
#
# -- param init $\in \{ 0.25, 0.50, 1.00, 1.50, 2.00, 3.00, 4.00 \}$
#
# | param value | average fitness |
# |------------:|----------------:|
# |        0.25 | 2 seeds  0.0748 |
# |        0.50 | 2 seeds  0.1034 |
# |        1.00 |          0.1223 |
# |        1.50 |          0.1354 |
# |        2.00 |          0.1441 |
# |      **3.00** |      **0.1775** |
# |        4.00 |          0.1481 |
